# %% [markdown]
# # Step 1: Evidence Details
#
# |System|Source of data|Frameworks|Purpose|
# |---|---|---|---|
# |Okta|Okta Applications|SOC 2|Get the list of users granted access to in-scope applications and groups.|
#
# ```
# RecommendedEvidenceName: OktaInscopeUserDetails
# ```

# %% [markdown]
# # Step 2: Define the System Specific Data

# %%
 # GET /api/v1/apps

[
    {
        "id": "0oajba7tllgSKPBO5d7",
        "orn": null,
        "name": "githubenterprisemanageduser",
        "label": "GitHub Enterprise Managed User",
        "status": "ACTIVE",
        "lastUpdated": "2024-08-29T20:14:35.000Z",
        "created": "2024-08-29T20:14:34.000Z",
        "accessibility": {
            "selfService": false,
            "errorRedirectUrl": null,
            "loginRedirectUrl": null
        },
        "visibility": {
            "autoLaunch": false,
            "autoSubmitToolbar": false,
            "hide": {
                "iOS": false,
                "web": false
            },
            "appLinks": {
                "githubenterprisemanageduser_link": true
            }
        },
        "features": [],
        "signOnMode": "SAML_2_0",
        "credentials": {
            "userNameTemplate": {
                "template": "${source.login}",
                "type": "BUILT_IN"
            },
            "signing": {
                "kid": "86UUp9aRWbo8I8uZuEYzo_ky1lVMGRqqFw23O-roqII"
            }
        },
        "settings": {
            "app": {
                "enterpriseName": null
            },
            "notifications": {
                "vpn": {
                    "network": {
                        "connection": "DISABLED"
                    },
                    "message": null,
                    "helpUrl": null
                }
            },
            "manualProvisioning": false,
            "implicitAssignment": false,
            "notes": {
                "admin": null,
                "enduser": null
            },
            "signOn": {
                "defaultRelayState": null,
                "ssoAcsUrlOverride": null,
                "audienceOverride": null,
                "recipientOverride": null,
                "destinationOverride": null,
                "honorForceAuthn": false,
                "attributeStatements": []
            }
        },
        "_links": {
            "help": {
                "href": "https://dev-93040161-admin.okta.com/app/githubenterprisemanageduser/0oajba7tllgrSKPBO5d7/setup/help/SAML_2_0/external-doc",
                "type": "text/html"
            },
            "metadata": {
                "href": "https://dev-93040161.okta.com/api/v1/apps/0oajba7tllgrSKPBO5d7/sso/saml/metadata",
                "type": "application/xml"
            },
            "uploadLogo": {
                "href": "https://dev-93040161.okta.com/api/v1/apps/0oajba7tllgrSKPBO5d7/logo",
                "hints": {
                    "allow": [
                        "POST"
                    ]
                }
            },
            "appLinks": [
                {
                    "name": "githubenterprisemanageduser_link",
                    "href": "https://dev-93040161.okta.com/home/githubenterprisemanageduser/0oajba7tllgrSKPBO5d7/aln1cphwkekAQBry20x7",
                    "type": "text/html"
                }
            ],
            "profileEnrollment": {
                "href": "https://dev-93040161.okta.com/api/v1/policies/rstgrqnvzeeaXUdCU5d7"
            },
            "policies": {
                "href": "https://dev-93040161.okta.com/api/v1/apps/0oajba7tllgrSKPBO5d7/policies",
                "hints": {
                    "allow": [
                        "PUT"
                    ]
                }
            },
            "groups": {
                "href": "https://dev-93040161.okta.com/api/v1/apps/0oajba7tllgrSKPBO5d7/groups"
            },
            "logo": [
                {
                    "name": "medium",
                    "href": "https://ok12static.oktacdn.com/fs/bcg/4/gfs78ql02esg1Vkuz5d7",
                    "type": "image/png"
                }
            ],
            "accessPolicy": {
                "href": "https://dev-93040161.okta.com/api/v1/policies/rstgrqkr8aYOECHL75d7"
            },
            "users": {
                "href": "https://dev-93040161.okta.com/api/v1/apps/0oajba7tllgrSKPBO5d7/users"
            },
            "deactivate": {
                "href": "https://dev-93040161.okta.com/api/v1/apps/0oajba7tllgrSKPBO5d7/lifecycle/deactivate"
            }
        }
    }
]

#Get api/v1/apps/{appID}/users
[
    {
        "id": "00uhswjyxtX2saPGS5d7",
        "externalId": "john.doe@example.com",
        "created": "2024-09-06T09:51:53.000Z",
        "lastUpdated": "2024-09-06T13:20:02.000Z",
        "scope": "USER",
        "status": "PROVISIONED",
        "statusChanged": "2024-09-06T09:51:54.000Z",
        "passwordChanged": null,
        "syncState": "SYNCHRONIZED",
        "lastSync": "2024-09-06T13:20:02.000Z",
        "credentials": {
            "userName": "sangavi.l@continube.com"
        },
        "profile": {
            "firstName": "John",
            "lastName": "Doe",
            "role": "AWSServiceRoleForAmazonEKS",
            "mobilePhone": null,
            "secondEmail": null,
            "samlRoles": [
                "Okta-AmazonS3FullAccess",
                "Okta-AmazonVPCReadOnlyAccess"
            ],
            "email": "john.doe@example.com",
            "idpRolePairs": []
        },
        "_links": {
            "app": {
                "href": "https://dev-93040161.okta.com/api/v1/apps/0oajglnofx4kHIEU75d7"
            },
            "user": {
                "href": "https://dev-93040161.okta.com/api/v1/users/00uhswjyxtX2zSPGS5d7"
            }
        }
    }
]

# %% [markdown]
# # Step 2a: Define the Extended Schema

# %%
[
    {
      "System": "okta",
      "Source": "compliancecow",
      "ResourceID": "00ujsabn3erxBPtWduc5d7",
      "ResourceName": "John Doe",
      "ResourceType": "User",
      "ResourceLocation": "N/A",
      "ResourceTags": "N/A",
      "ResourceURL": "https://dev-93044161-admin.okta.com/admin/user/profile/view/00ujbn3erxBPtWduc5d7#tab-account",
      "UserEmail": "johndoe@example.com",
      "UserGroups": [
          {
              "GroupID": "00ghaqe3cgSQWYM2n5d7",
              "GroupName": "TestGroup"
          },
          {
              "GroupID": "00gjlhr1ud4bQmfr95d7",
              "GroupName": "DevOps Engineer"
          },
          {
              "GroupID": "00gjlhrxg7JG6oSsr5d7",
              "GroupName": "ComplianceCow Developer"
          }
      ],
      "UserIsAdmin": true,
      "UserAdminRoles": [
          "Super Administrator"
      ],
      "UserCreatedDate": "2024-08-30T10:16:54.000Z"
    }
]

# %% [markdown]
# # Step 3: Define the Standard Schema

# %%
[
    {
        "System": "okta",
        "Source": "compliancecow",
        "ResourceID": "00uhswjyxtX2zSPGS5d7",
        "ResourceName": "John Doe",
        "ResourceType": "User",
        "ResourceLocation": "N\/A",
        "ResourceTags": "N\/A",
        "ResourceURL": "https:\/\/dev-934040161-admin.okta.com\/admin\/user\/profile\/view\/00uhswjyxtX2zSPGS5d7#tab-account",
        "UserEmail": "johndoe@example.com",
        "UserIsAdmin": true,
        "UserAdminRoles": [
            "Super Administrator"
        ],
        "UserCreatedDate": "2024-06-18T00:19:22.000Z",
        "UserLastLogin": "2024-09-11T04:55:30.000Z",
        "UserGroups": [
            {
                "GroupID": "00gjlhr1ud4bQmfr95d7",
                "GroupName": "DevOps Engineer"
            },
            {
                "GroupID": "00gjlhrxg7JG6oSsr5d7",
                "GroupName": "ComplianceCow Developer"
            }
        ],
        "Roles": {
            "GitHub Enterprise - ComplianceCow": [
                "user"
            ],
            "AWS ComplianceCow Sandbox": [
                "AWSServiceRoleForAmazonEKS",
                "Okta-AmazonS3FullAccess",
                "Okta-AmazonVPCReadOnlyAccess"
            ]
        },
        "UserApplications": [
            "GitHub Enterprise - ComplianceCow",
            "AWS ComplianceCow Sandbox"
        ],
        "ValidationStatusCode": "USR_IN_SCP_APP_AND_GRP",
        "ValidationStatusNotes": "User is part of in-scope application and in-scope group.",
        "EvaluatedTime": "2024-09-12T10:50:14.768046Z",
        "UserAction": "",
        "ActionStatus": "",
        "ActionResponseURL": ""
    }
]

# %% [markdown]
# # Step 3.b: Sample Data
#
# |System|Source|ResourceID|ResourceName|ResourceType|ResourceLocation|ResourceTags|ResourceURL|UserEmail|UserIsAdmin|UserAdminRoles|UserCreatedDate|UserLastLogin|UserGroups|Roles|UserApplications|ValidationCode|ValidationNotes|EvaluatedTime|UserAction|ActionStatus|ActionStatus|
# |---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|
# |okta|compliancecow|0eujerfj28IEwrf5d7|John Github|User|N/A|N/A|https://dev-930461-admin.okta.com/admin/user/profile/view/00ujbn3erxBPtWduc5d7#tab-account|john.doe@example.com|true|Super Administrator|2024-08-30T10:16:54.000Z|2024-09-05T08:37:44.000Z|[{"GroupID": "00gjep16zyPWMDFX5d7","GroupName": "SampleGroup"}]|{"GitHub Enterprise - ComplianceCow": ["user"], "AWS ComplianceCow Sandbox": [ "AWSServiceRoleForAmazonEKS", "Okta-AmazonS3FullAccess","Okta-AmazonVPCReadOnlyAccess"]}|["GitHub Enterprise - ComplianceCow", "AWS ComplianceCow Sandbox"]|USR_IN_SCP_APP_AND_GRP|User is part of in-scope application and in-scope group.|2024-09-09T10:16:30.488578Z||||

# %% [markdown]
# # Step 4: Describe the Compliance Taxonomy
#
# |Validation Code|Validation Status|
# |---|---|
# |USR_IN_SCP_APP_AND_GRP| User is part of in-scope application and in-scope group.|
# |USR_IN_SCP_APP_ONLY| User is part of in-scope applications but not part of any in-scope groups.|
# |USR_IN_SCP_GRP_ONLY| User is not part of any in-scope applications but is part of in-scope groups.|
# |USR_NOT_IN_SCP| User is not part of any in-scope applications and is not part of any in-scope groups.|

# %% [markdown]
# # Step 5: Control Setup Details

# %% [markdown]
# | Control Details            |                                               |
# |----------------------------|-----------------------------------------------|
# | **RuleName**               |GetOktaInscopeUserDetails                             |
# | **PreRequisiteRuleNames**  | N/A                                           |
# | **ExtendedSchemaRuleNames**| N/A                                           |
# | **ApplicationClassName**   | oktaconnector                              |
# | **PostSynthesizerName**    | N/A                                           |
